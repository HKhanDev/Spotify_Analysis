# %% [markdown]
# <a href="https://colab.research.google.com/github/sherlock-99/Spotify_Analysis/blob/main/Spotify_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('tracks.csv')

# %%
data
# Out:
#                             id                                   name  \
# 0       35iwgR4jXetI318WEWsa1Q                                  Carve
# 1       021ht4sdgPcrDgSk7JTbKY    Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc     Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45          El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                    Lady of the Evening
# ...                        ...                                    ...
# 205879  4KDPfE6F3gGMeFjmmxO0CG                                  Amigo
# 205880  0cOdqAW2SzvoGrIJ8U8J2g                                Pagarás
# 205881  0DVjdZF5Y4bWMJvlQesfEE                         Fuego En El 23
# 205882  24c5K7vB2ZGJ6JqC2xCciJ  Símbolo Sexual - Versão Remasterizada
# 205883  7leCLAp6UrW2g0tLoDc5aW                     Sólo una Noche Más
#
#         popularity  duration_ms  explicit                  artists  \
# ...
